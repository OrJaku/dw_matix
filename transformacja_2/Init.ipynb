# %%
cd drive/My Drive/Colab Notebooks/
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
cd dw_matix
# Out:
# [Errno 2] No such file or directory: 'dw_mattix'
# /content/drive/My Drive/Colab Notebooks/dw_matrix_2

# %%
cd dw_matrix_2/
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix_2

# %%
GIT_TOKEN = "54e8b922abf625f2b3793ee9eff3aa311df9a550"

# %%
GIT_URL = 'https://{}@github.com/OrJaku/dw_matix.git'.format(GIT_TOKEN)

# %%
# !git clone $GIT_URL
# Out:
# Cloning into 'dw_matix'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 48 (delta 18), reused 20 (delta 5), pack-reused 0
# Unpacking objects: 100% (48/48), done.

# %%
mkdir dw_matix/transformacja_2

# %%
# !git config --global user.email "kuba.orzel@hotmail.com"
# !git config --global user.name "OrJaku"

# %%
# !git add .
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git status
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
